# %%
from PyAWD.VectorialAcousticWaveDataset import VectorialAcousticWaveDataset

# %%
d = VectorialAcousticWaveDataset(1, nx=64, t=10, interrogators=[(-10, 0), (10, 0)], velocity_model="Marmousi")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#d.generate_video(0, "test", 100)

# %%
d.plot_item(0)

# %%
d.plot_interrogators_response(0)
