# %%
from pyawd import VectorAcousticWaveDataset

# %%
d = VectorAcousticWaveDataset(1, nx=64, t=10, interrogators=[(-10, 0), (10, 0)], velocity_model="Marmousi")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
d.generate_video(0, "VectorAcousticWaveDataset", 100)
# Out:
# Generating 100 images.
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
d.plot_item(0)

# %%
d.plot_interrogators_response(0)
