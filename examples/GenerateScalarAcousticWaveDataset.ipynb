# %%
import numpy as np
import devito as dvt
import matplotlib.pyplot as plt
import torch
from tqdm.notebook import tqdm

from PyAWD.GenerateVideo import *
from PyAWD.utils import *
from PyAWD.Marmousi import *
from PyAWD.ScalarAcousticWaveDataset import *

GENERATING = True

# %%
size = 50
nx = 128
ddt = 0.01
dt = 2
t = 10
batch_size = 10

if GENERATING:
    dataset = ScalarAcousticWaveDataset(size=size, nx=nx, ddt=ddt, dt=dt, t=t)
    torch.save(dataset, '../../../local/dev.pt')
else:
    dataset = torch.load('../../../local/dev.pt')
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
dataset.plot_item(0)

# %%
dataset.generate_video(0, "dataset_generation", 100)
# Out:
# Generating 100 images.
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# %%HTML
# <video width="640" controls>
#   <source src="dataset_generation.mp4" type="video/mp4">
# </video>
# Out:
# <video width="640" controls>
#   <source src="dataset_generation.mp4" type="video/mp4">
# </video>
